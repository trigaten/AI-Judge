# %%
import utils
df = utils.read_json("example.json")
utils.tokenize_df(df).head()
# Out:
#                                                 body judgement  \
# 0  [AITA, for, giving, my, group, member, a, bad,...       YTA
# 1  [AITA, for, giving, my, group, member, a, bad,...       YTA
# 2  [AITA, for, giving, my, group, member, a, bad,...       YTA
#
#                                         comment_body
# 0  [YTA, She, contributed, to, the, project, (, m...
# 1  [YTA, She, contributed, to, the, project, (, m...
# 2  [YTA, She, contributed, to, the, project, (, m...
