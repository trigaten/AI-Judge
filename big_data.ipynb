# %%
from data_processing import read_csv
from data_processing import freq_map
from data_processing import test_freqs
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to /Users/sander/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sander/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = read_csv(samples=200)

X_train, X_test, y_train, y_test = train_test_split(data.drop(['is_asshole'], axis=1), data['is_asshole'], test_size=0.20, shuffle=True)

# %%
words = freq_map(X_train, y_train)
prior_ratio = len(data.query("is_asshole == 1"))/len(data.query("is_asshole == 0"))

# %%
d_test = pd.concat([X_test, y_test], axis=1)
test_freqs(d_test, words, prior_ratio = prior_ratio)

# %%
# len(d_test.query("is_asshole != pred_label"))/len(d_test)
# d_test.query("is_asshole == 1")
for key in words:
    data = wordclones[key]
# Out:
# {'thi': namespace(pos_freq=0.010414580412577609,
#            neg_freq=0.012550974173085637),
#  'first': namespace(pos_freq=0.0013018225515722011,
#            neg_freq=0.0020389669234254643),
#  'post': namespace(pos_freq=0.0012016823552974164,
#            neg_freq=0.0011327594019030357),
#  'aita': namespace(pos_freq=0.00170238333667134,
#            neg_freq=0.0024920706841866785),
#  'go': namespace(pos_freq=0.006208692169036651, neg_freq=0.006977797915722701),
#  'tri': namespace(pos_freq=0.0028039254956939716,
#            neg_freq=0.003443588581785229),
#  'best': namespace(pos_freq=0.0005007009813739235,
#            neg_freq=0.0013140009062075216),
#  'break': namespace(pos_freq=0.0008011215701982776,
#            neg_freq=0.0006343452650657),
#  'ani': namespace(pos_freq=0.0015021029441217705,
#            neg_freq=0.001993656547349343),
#  'rule': namespace(pos_freq=0.0003004205888243541,
#            neg_freq=0.0003624830086089715),
# ...

# %%
confusion_matrix(d_test['is_asshole'], d_test['pred_label'])

# len(d_test.query("is_asshole == 0"))
# len(d_test)
# words
# d_test.query("pred_label==1")
# print(d_test)
# Out:
# array([[399,  58],
#        [120,  23]])

# %%
test_dframe = pd.DataFrame({'title': ["HE hit me"], 'body': ["not my fault"], "link_flair_text":"Asshole"})
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=2, test_size=0.2)
sss
# Out:
# StratifiedShuffleSplit(n_splits=2, random_state=None, test_size=0.2,
#             train_size=None)

# %%
pos = 0
neg = 0
for word in words:
    pos+= words[word].pos_freq
    neg+= words[word].neg_freq
